# %%
import numpy as np

from astropy import units as u
from astropy.constants import G 
from astropy.coordinates import SkyCoord

# %%
Reff = 30 * u.pc
Reff
# Out:
# <Quantity 30.0 pc>

# %%
SkyCoord(1.6*u.deg, 11.6*u.deg)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     ( 1.6,  11.6)>

# %%
star = SkyCoord.from_name('Sirius')
star
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     ( 101.2885408, -16.7131428)>

# %%
SkyCoord(101.2885408*u.deg, -16.7131428*u.deg)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     ( 101.2885408, -16.7131428)>

# %%
polaris = SkyCoord.from_name('Regulus')
polaris
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     ( 152.1170833,  12.3063889)>

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [1, 0],
            [4, 2], [4, 4], [4, 0]])
kmeans = KMeans(n_clusters=2, init='k-means++').fit(X)
kmeans.labels_
# Out:
# array([0, 0, 0, 1, 1, 1])

# %%
X
# Out:
# array([[1, 2],
#        [1, 4],
#        [1, 0],
#        [4, 2],
#        [4, 4],
#        [4, 0]])

# %%
kmeans.predict([[0, 0], [4, 4]])
# Out:
# array([0, 1])

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.,  2.],
#        [ 4.,  2.]])

# %% [markdown]
# # To use

# %%
allign.figures()

# %%
from IPython.display import Image
Image(filename='D:\SoftUni\Machine Learning\The Bulgarian Zodiac Project\SofiaNihtSky\SofiaNightSky_0_15.04.2017_10PM.png')

# %%
import plotly.plotly as py
from plotly.graph_objs import *
import scipy as sp
import plotly.plotly as py

import numpy as np

s = np.linspace(0, 2 * np.pi, 240)
t = np.linspace(0, np.pi, 240)
tGrid, sGrid = np.meshgrid(s, t)

r = 2 + np.sin(7 * sGrid + 5 * tGrid)  # r = 2 + sin(7s+5t)
x = r * np.cos(sGrid) * np.sin(tGrid)  # x = r*cos(s)*sin(t)
y = r * np.sin(sGrid) * np.sin(tGrid)  # y = r*sin(s)*sin(t)
z = r * np.cos(tGrid)                  # z = r*cos(t)

surface = Surface(x=x, y=y, z=z)
data = Data([surface])

layout = Layout(
    title='Parametric Plot',
    scene=Scene(
        xaxis=XAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        yaxis=YAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        zaxis=ZAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        )
    )
)

fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='jupyter/parametric_plot')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b8f58a8475ce> in <module>()
#       1
# ----> 2 import plotly.plotly as py
#       3 from plotly.graph_objs import *
#       4 import scipy as sp
#       5 import plotly.plotly as py
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Scatter(x=[1,2,3], y=[4,5,6], marker={'color': 'red', 'symbol': 104, 'size': "10"}, 
                    mode="markers+lines",  text=["one","two","three"], name='1st Trace')
                                               
data=go.Data([trace1])
layout=go.Layout(title="First Plot", xaxis={'title':'x1'}, yaxis={'title':'x2'})
figure=go.Figure(data=data,layout=layout)
py.iplot(figure, filename='pyguide_1')

# %%
birth_month = input('Please enter your birth month: ')

if birth_month == "January": print('Your real sign is 1')
elif birth_month == "February": print('Your real sign is 2')
elif birth_month == "March": print('Your real sign is 2')
elif birth_month == "April": print('Your real sign is 2')
elif birth_month == "May": print('Your real sign is 2')
elif birth_month == "June": print('Your real sign is 2')
elif birth_month == "July": print('Your real sign is 2')
elif birth_month == "August": print('Your real sign is 2')
elif birth_month == "September": print('Your real sign is 2')
elif birth_month == "October": print('Your real sign is 2')
elif birth_month == "November": print('Your real sign is 2')
elif birth_month == "December": print('Your real sign is 2')
else: print(input('Your imput is wrong. Plese write your birth month in English, with capital letter.')

# %%
print("a")

# %%
from IPython.display import Image
one = Image.open(filename='D:\SoftUni\Machine Learning\The Bulgarian Zodiac Project\SofiaNihtSky\SofiaNightSky_0_15.04.2017_10PM.png')
one
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-058f086dc650> in <module>()
#       1 from IPython.display import Image
# ----> 2 one = Image.open(filename='D:\SoftUni\Machine Learning\The Bulgarian Zodiac Project\SofiaNihtSky\SofiaNightSky_0_15.04.2017_10PM.png')
#       3 one
#
# AttributeError: type object 'Image' has no attribute 'open'

# %%
birth_month = input('Please enter your birth month: ')

if birth_month == "January": print('Your real sign is 1')
    one
elif birth_month == "February": print('Your real sign is 2')

# %%
from IPython.display import Image, display

listOfImageNames = ['D:\SoftUni\Machine Learning\The Bulgarian Zodiac Project\SofiaNihtSky\SofiaNightSky_0_15.04.2017_10PM.png',
                    'D:\SoftUni\Machine Learning\The Bulgarian Zodiac Project\SofiaNihtSky\SofiaNightSky_0_15.04.2017_10PM.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
